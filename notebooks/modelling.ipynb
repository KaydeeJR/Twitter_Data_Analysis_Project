# %% [markdown]
# # **Table of Contents:**
# * [File access](#access)
# * [Topic modelling](#modelling)
#     * [Dictionary corpus](#corpus)
#     * [Bag of words model](#bow)
#     * [LDA model](#lda)
# * [Visualizing results](#visualizing)
#     * [Topic visualization using pyLDAvis](#topics)
#     * [Word cloud](#cloud)

# %% [markdown]
# # File access<a class="anchor" id="access"></a>

# %%
import os
import sys

directory_path = os.path.dirname(os.getcwd())
sys.path.append(directory_path + "\\utils")
sys.path.append(directory_path + "\\scripts")
sys.path.append(directory_path + "\\notebooks")

# %%
project_base = os.path.dirname(os.getcwd())
data_folder = project_base + r"\data"

# %%
from topic_modelling import TopicModelling
import pyLDAvis
import pickle
import pandas as pd

# %%
tweets_df = pd.read_json(data_folder+r"\global_twitter_data.json", lines=True)

# %%
with open('words_list.pkl', 'rb') as f:
    words_list = pickle.load(f)

# %% [markdown]
# # Topic modelling<a class="anchor" id="modelling"></a>

# %%
topic_model = TopicModelling()

# %% [markdown]
# ## Dictionary corpus<a class="anchor" id="corpus"></a>

# %%
tweet_mappings = topic_model.make_dictionary(words_list)

# %%
parent_dir = os.path.dirname(os.getcwd())
topic_model.save_dictionary(tweet_mappings,'global_mappings')

# %% [markdown]
# ## Bag of words model<a class="anchor" id="bow"></a>

# %%
bow = topic_model.create_bow(words_list, tweet_mappings)
topic_model.serialize_bow('global_bow',bow)

# %% [markdown]
# ## LDA model<a class="anchor" id="lda"></a>

# %% [markdown]
# **Reading from files in current directory in order to avoid recreating the mappings and bow**

# %%
saved_bow = topic_model.load_bow('global_bow')
saved_mapping = topic_model.load_dictionary('global_mappings')

# %%
lda = topic_model.create_lda_model(saved_bow, saved_mapping)

# %% [markdown]
# **Creating the LDA model takes approximately 50s**
#
# Saving the LDA model in order to avoid recreating it and save substantial computing time

# %%
topic_model.save_lda_model(lda, 'global_lda')

# %% [markdown]
# # Visualizing results<a class="anchor" id="visualizing"></a>

# %%
lda_model = topic_model.load_lda_model('global_lda')

# %% [markdown]
# ## Topic visualization using pyLDAvis<a class="anchor" id="topics"></a>

# %% [markdown]
# The pyLDAvis package produces an interactive plot where each circle is a topic and the size of the circle represents the abundance of that topic in the corpus.
#
# Along with each topic are the associated words that go with it.

# %%
pyLDAvis.enable_notebook()
lda_visualisation = topic_model.visualize_lda_results(lda_model, saved_bow, saved_mapping)
display(lda_visualisation)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 49     0.084334  0.058707       1        1  10.461438
# 33     0.074525  0.047113       2        1   9.838040
# 20     0.124562  0.038878       3        1   8.762255
# 15     0.107418  0.036970       4        1   5.996322
# 16     0.131977  0.038673       5        1   5.783684
# 41     0.098028  0.002024       6        1   3.872912
# 34     0.142034  0.028141       7        1   3.821341
# 25     0.138202 -0.027434       8        1   3.397198
# 28     0.103606  0.041994       9        1   3.192463
# 22     0.121841  0.017553      10        1   2.879239
# 38     0.116625  0.018606      11        1   2.641761
# 11     0.082937 -0.036560      12        1   2.405022
# 46     0.101584 -0.034739      13        1   2.319215
# 13     0.102097  0.008851      14        1   2.285812
# 4      0.100507  0.006885      15        1   2.016477
# 35     0.103985  0.021929      16        1   2.002393
# ...

# %%
topic_model.save_lda_result(lda_visualisation, 'global_lda_viz')
# Out:
# True

# %% [markdown]
# ## Word cloud<a class="anchor" id="cloud"></a>

# %%
# If there is a mask available to apply in the word cloud
project_base = os.path.dirname(os.getcwd())
res_folder = project_base + r"\res"

# %%
topic_model.create_word_cloud(words_list, res_folder+'./twitter.png')
# Out:
# c:\Users\LENOVO\personal_repos\Twitter_Data_Analysis_Project\tweets\Lib\site-packages\wordcloud\wordcloud.py:106: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   self.colormap = plt.cm.get_cmap(colormap)
